# %% [markdown]
# # Laplace Approximation
#
# Las distribuciones:
# $$ p(x) \alpha  e^{-x^2/2}\sigma(20x+4) \\
# \sigma(x) = (1+e^{-x})^{-1}$$

# %%
import numpy as np
import matplotlib.pyplot as plt
from scipy.optimize import minimize
from scipy.misc import derivative
from scipy.stats import norm
from scipy.integrate import quad,dblquad
# %matplotlib inline

# %%
Sigmoid = lambda x: (1+np.exp(1)**(-x))**-1
P = lambda x: np.exp(1)**(-(x**2)/2)*Sigmoid(20*x+4)

# %%
def LaplaceAproximation(Ps):
    ### Calculo de parametros
    
    Pformin = lambda x: -1*Ps(x)
    mu = minimize(Pformin,0).x
    logp = lambda x: np.log(Ps(x))
    A = -1*derivative(logp, mu, dx=1e-6,n=2)[0]
    sigma = np.sqrt(A**(-1))
    z = Ps(mu)*np.sqrt(2*np.pi*(sigma**2))
    
    ## Plot 
    x = np.linspace(-4,5,100)
    plt.plot(x,Ps(x),alpha=0.6,lw=5)
    plt.plot(x, norm.pdf(x,loc=mu, scale=sigma)*z,'r-', lw=5, alpha=0.6)

# %%
LaplaceAproximation(P)

# %% [markdown]
# # KL Reverse Divergence

# %%
from scipy.stats import multivariate_normal
import matplotlib.mlab as mlab


mu1 = [1,1]
cov1 =[[2,0.1],[0.1,1]]
mu2 = [8,8]
cov2 =[[2,0.8],[0.5,1]]
delta = 0.025
w=0.6

# %%
### Funciones 

def Comb_variables(X,Y,mu1,mu2,cov1,cov2,w):
    return w*mlab.bivariate_normal(X, Y, sigmax=cov1[0][0], sigmay=cov1[1][1], mux=mu1[0], muy=mu1[0], sigmaxy=cov1[1][0])+(1-w)*mlab.bivariate_normal(X, Y, sigmax=cov2[0][0], sigmay=cov2[1][1], mux=mu2[0], muy=mu2[0], sigmaxy=cov2[1][0])

def DevolverPuntos(z1,z2):
    points = [list(z1[0])+list(z2[0]),list(z1[1])+list(z2[1])]
    return points
def GenerarPuntos(mu1,mu2,cov1,cov2,w,delta):
    x = np.arange(-4.0, 16.0, delta)
    y = np.arange(-4.0, 16.0, delta)
    X, Y = np.meshgrid(x, y)
    z = Comb_variables(X,Y,mu1,mu2,cov1,cov2,w)
    plt.contour(X, Y, z)
    return(z1)

# %%
z = GenerarPuntos(mu1,mu2,cov1,cov2,w,delta)

# %%
def Q(x,mean,cov):
    return multivariate_normal.pdf(x,mean=mean,cov=cov)
def P(x,mu1,mu2,cov1,cov2,w):
    return w*multivariate_normal.pdf(x,mean=mu1,cov=cov1)+(1-w)*multivariate_normal.pdf(x,mean=mu2,cov=cov2)
def IntegrandoReverse(x,qmean,qcov,mu1,mu2,cov1,cov2,w):
    return Q(x,qmean,qcov)*np.log(Q(x,qmean,qcov)/P(x,mu1,mu2,cov1,cov2,w))
def IntegrandoForward(x,qmean,qcov,mu1,mu2,cov1,cov2,w):
    return P(x,mu1,mu2,cov1,cov2,w)*np.log(P(x,mu1,mu2,cov1,cov2,w)/Q(x,qmean,qcov))

# %%
qcov = cov1
# Out:
# -0.040126130121021619

# %%
IReverse = lambda x ,qmean: IntegrandoReverse(x,qmean,qcov,mu1,mu2,cov1,cov2,w)
IForward = lambda x,qmean: IntegrandoForward(x,qmean,qcov,mu1,mu2,cov1,cov2,w)
KLReverse = lambda qmean : dblquad(IReverse, 0, 12, lambda x: 0, lambda x: 12)

# %%
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-80-42e8bcbfe615> in <module>()
#       1 # Calculo Minimos
# ----> 2 KLReverse((0,1))
#       3
#
# <ipython-input-79-fa1a12b0c1e2> in <lambda>(qmean)
#       1 IReverse = lambda x ,qmean: IntegrandoReverse(x,qmean,qcov,mu1,mu2,cov1,cov2,w)
#       2 IForward = lambda x,qmean: IntegrandoForward(x,qmean,qcov,mu1,mu2,cov1,cov2,w)
# ----> 3 KLReverse = lambda qmean : dblquad(IReverse, 0, 12, lambda x: 0, lambda x: 12)
#
# /usr/local/lib/python3.6/site-packages/scipy/integrate/quadpack.py in dblquad(func, a, b, gfun, hfun, args, epsabs, epsrel)
#     504         return [gfun(args[0]), hfun(args[0])]
#     505     return nquad(func, [temp_ranges, [a, b]], args=args,
# --> 506             opts={"epsabs": epsabs, "epsrel": epsrel})
#     507
#     508
#
# /usr/local/lib/python3.6/site-packages/scipy/integrate/quadpack.py in nquad(func, ranges, args, opts, full_output)
#     712     else:
#     713         opts = [opt if callable(opt) else _OptFunc(opt) for opt in opts]
# --> 714     return _NQuad(func, ranges, opts, full_output).integrate(*args)
#     715
#     716
#
# /usr/local/lib/python3.6/site-packages/scipy/integrate/quadpack.py in integrate(self, *args, **kwargs)
#     767             f = partial(self.integrate, depth=depth+1)
#     768         quad_r = quad(f, low, high, args=args, full_output=self.full_output,
# --> 769                       **opt)
#     770         value = quad_r[0]
#     771         abserr = quad_r[1]
#
# /usr/local/lib/python3.6/site-packages/scipy/integrate/quadpack.py in quad(func, a, b, args, full_output, epsabs, epsrel, limit, points, weight, wvar, wopts, maxp1, limlst)
#     321     if (weight is None):
#     322         retval = _quad(func, a, b, args, full_output, epsabs, epsrel, limit,
# --> 323                        points)
#     324     else:
#     325         retval = _quad_weight(func, a, b, args, full_output, epsabs, epsrel,
#
# /usr/local/lib/python3.6/site-packages/scipy/integrate/quadpack.py in _quad(func, a, b, args, full_output, epsabs, epsrel, limit, points)
#     386     if points is None:
#     387         if infbounds == 0:
# --> 388             return _quadpack._qagse(func,a,b,args,full_output,epsabs,epsrel,limit)
#     389         else:
#     390             return _quadpack._qagie(func,bound,infbounds,args,full_output,epsabs,epsrel,limit)
#
# /usr/local/lib/python3.6/site-packages/scipy/integrate/quadpack.py in integrate(self, *args, **kwargs)
#     767             f = partial(self.integrate, depth=depth+1)
#     768         quad_r = quad(f, low, high, args=args, full_output=self.full_output,
# --> 769                       **opt)
#     770         value = quad_r[0]
#     771         abserr = quad_r[1]
#
# /usr/local/lib/python3.6/site-packages/scipy/integrate/quadpack.py in quad(func, a, b, args, full_output, epsabs, epsrel, limit, points, weight, wvar, wopts, maxp1, limlst)
#     321     if (weight is None):
#     322         retval = _quad(func, a, b, args, full_output, epsabs, epsrel, limit,
# --> 323                        points)
#     324     else:
#     325         retval = _quad_weight(func, a, b, args, full_output, epsabs, epsrel,
#
# /usr/local/lib/python3.6/site-packages/scipy/integrate/quadpack.py in _quad(func, a, b, args, full_output, epsabs, epsrel, limit, points)
#     386     if points is None:
#     387         if infbounds == 0:
# --> 388             return _quadpack._qagse(func,a,b,args,full_output,epsabs,epsrel,limit)
#     389         else:
#     390             return _quadpack._qagie(func,bound,infbounds,args,full_output,epsabs,epsrel,limit)
#
# <ipython-input-79-fa1a12b0c1e2> in <lambda>(x, qmean)
# ----> 1 IReverse = lambda x ,qmean: IntegrandoReverse(x,qmean,qcov,mu1,mu2,cov1,cov2,w)
#       2 IForward = lambda x,qmean: IntegrandoForward(x,qmean,qcov,mu1,mu2,cov1,cov2,w)
#       3 KLReverse = lambda qmean : dblquad(IReverse, 0, 12, lambda x: 0, lambda x: 12)
#
# <ipython-input-71-68bd6fd5ec0a> in IntegrandoReverse(x, qmean, qcov, mu1, mu2, cov1, cov2, w)
#       4     return w*multivariate_normal.pdf(x,mean=mu1,cov=cov1)+(1-w)*multivariate_normal.pdf(x,mean=mu2,cov=cov2)
#       5 def IntegrandoReverse(x,qmean,qcov,mu1,mu2,cov1,cov2,w):
# ----> 6     return Q(x,qmean,qcov)*np.log(Q(x,qmean,qcov)/P(x,mu1,mu2,cov1,cov2,w))
#       7 def IntegrandoForward(x,qmean,qcov,mu1,mu2,cov1,cov2,w):
#       8     return P(x,mu1,mu2,cov1,cov2,w)*np.log(P(x,mu1,mu2,cov1,cov2,w)/Q(x,qmean,qcov))
#
# <ipython-input-71-68bd6fd5ec0a> in Q(x, mean, cov)
#       1 def Q(x,mean,cov):
# ----> 2     return multivariate_normal.pdf(x,mean=mean,cov=cov)
#       3 def P(x,mu1,mu2,cov1,cov2,w):
#       4     return w*multivariate_normal.pdf(x,mean=mu1,cov=cov1)+(1-w)*multivariate_normal.pdf(x,mean=mu2,cov=cov2)
#       5 def IntegrandoReverse(x,qmean,qcov,mu1,mu2,cov1,cov2,w):
#
# /usr/local/lib/python3.6/site-packages/scipy/stats/_multivariate.py in pdf(self, x, mean, cov, allow_singular)
#     502
#     503         """
# --> 504         dim, mean, cov = self._process_parameters(None, mean, cov)
#     505         x = self._process_quantiles(x, dim)
#     506         psd = _PSD(cov, allow_singular=allow_singular)
#
# /usr/local/lib/python3.6/site-packages/scipy/stats/_multivariate.py in _process_parameters(self, dim, mean, cov)
#     387         if dim == 1:
#     388             mean.shape = (1,)
# --> 389             cov.shape = (1, 1)
#     390
#     391         if mean.ndim != 1 or mean.shape[0] != dim:
#
# ValueError: cannot reshape array of size 4 into shape (1,1)
